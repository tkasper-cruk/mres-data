# %%
import pandas as pd
import itertools as it
import multiprocessing as mp
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
workflow_dir = Path("") #absolute path to the root of the cell matching workflow (cell_matching)
results_dir = Path("") #absolute path to the scores directory
n_cells = 760 #adjust
n_bootstrap = 250 #adjust

# %%
gt = {}
with open(workflow_dir / 'matched_barcodes.tsv','r') as ih: #adjust as needed
    _ = ih.readline()
    for line in ih:
        parts = line.strip().split("\t")
        gt[parts[1]] = parts[0]
len(gt)
# Out:
# 736320

# %%
def resolve_replicate(rep)->list[dict[str,str|int|float]]:
    res = []

    top_ns = [1,5,10,25,50,100]
    metrics = ["cosine","pearson","spearman","kendall"]
    tools = ["rna","copykat","copyvae"]
    for tool in tools:
        for metric in metrics:
            df = pd.read_csv(results_dir/f'replicate_{rep}_{tool}_{metric}.tsv',sep='\t',index_col=0).iloc[:n_cells,n_cells:]
            recalls = {x:0 for x in top_ns}
            duplicates = []
            for c in df.columns:
                ranked_index = df[c].apply(abs).sort_values(ascending=False).index
                max_score = df[c].apply(abs).max()
                duplicates.append(len([x for x in df[c] if abs(x) >= max_score]))
                for n in top_ns:
                    recalls[n] += gt[c] in ranked_index[:n]
            for n in top_ns:
                res.append({
                    "metric":metric,
                    "tool" : tool,
                    "top_n" : n,
                    "recall" : recalls[n] / df.shape[1],
                    "min_duplicates" : min(duplicates),
                    "max_duplicates" : max(duplicates),
                    "median_duplicates" : np.median(duplicates),
                    "mean_duplicates" : np.mean(duplicates)
                })
        print(rep,tool)
    randoms = {x:0 for x in top_ns}
    cnt = 0
    for c in df.columns:
        random_calls = df[c].apply(abs).sample(frac=1,random_state=rep+cnt).index
        cnt += 1
        for n in top_ns:
            randoms[n] += gt[c] in random_calls[:n]
    for n in top_ns:
        res.append({
            "metric":"random",
            "tool" : "other",
            "top_n" : n,
            "recall" : randoms[n] / df.shape[1],
            "min_duplicates" : 1,
            "max_duplicates" : 1,
            "median_duplicates" : 1,
            "mean_duplicates" : 1
        })
    return res

if __name__ == "__main__":
    results = []
    p = mp.Pool()
    for r in p.map_async(resolve_replicate,range(1,n_bootstrap+1)).get():
        results += r    
    recall_df = pd.DataFrame(results)
# Out:
# 11327 rna
# 21
#  45rna
# 5512  rnarna
# rna20 rnarna3
#  rna
# 39rna 176097rna
# rnarna
# 40
#  rnarna
#
#
#  rna
# 42 rna
# 63
# 3862 rna
# rna
# 19 rna
# 57rna
#
# 30 rna58 rna
# 11 rna
# rna
# 528
# 4659 43  rna
# rnarna
# 49rna rna
#
# 32 rna
#  rna
#
# 3724 rna
# 26  rna31
#  rna
# 1451  rnarna
#
# rna
#
# 35291018  rnarna 61rna
# rnarna
#
# 644  rnarna
#
# 4836  rnarna
#
# 64 rna
# 56
#  rna
# 15 54rna
#  rna
# 23 rna
# 412 rna
# 50 rna
# 33 rna
#  rna
# 5 rna
# 28 rna
# 22 rna
# 34 rna
# 4 rna
# 47 rna
# 53 rna
# 25 rna
# 16 rna
# 27 copykat
# 43 copykat
# 26 copykat
# 64 copykat
# 2 copykat
# 3411  copykat
# 31 copykat
# 4522  copykat
# 603 copykat
# copykat
# copykat44
# 36 copykat
#   copykatcopykat
# 8 copykat
# 23 copykat
# 33 copykat1618
#
#  copykatcopykatcopykat
#
# 30 37
# 9 copykat
# 40 58copykat
#  copykat
#  5 62copykat
# copykat35
# 14  copykat3248copykat
# copykat
#  47
# copykat12 copykat
# 452  copykatcopykat
#
# 3824 copykat  copykat
#
#
#
# 46 copykat copykat53 copykat
# 25 1copykat
#  copykat
# 57 copykatcopykat
# 21 copykat
#
# 42
#  copykat
#
# 59 copykat
# 55 copykat
# 50 copykat
# 28 copykat
# 10 copykat
# 7 copykat49 39copykat
#  copykat15 17copykat
# copykat
#
# 63 copykat
# 56 copykat296 copykat
# 54 5113
# 61 copykat
# 41 copykat
#  copykat
# copykatcopykat
#
# copykat
# 1920 copykat
# copykat
# 43 copyvae
# 64 copyvae
# 262  copyvaecopyvae
#
# 27 3411 copyvae
#  copyvaecopyvae
# 45
#  copyvae
# 22168 copyvae
# 30 copyvae copyvae
#
# 33 copyvae
# 9 copyvae
# copyvae623  copyvae
#
# 12
#  copyvae4 copyvae50copyvae
#  copyvae
# 53 copyvae
# 14 57copyvae23
#
# 31  copyvaecopyvae52
#  37 copyvaecopyvae25 copyvae
#
# 35 copyvae
#  1546
# copyvae
# copyvae48
#  copyvae10
# 28  copyvaecopyvae
# copyvae
#
# 36
# 59 copyvae42 copyvae
# 721
#   copyvae1  copyvae244439
#   copyvae
# copyvae
#
# copyvaecopyvae
# 58
#  copyvaecopyvae18
#  copyvae
# 6040 copyvae
# 51 copyvae
#
# 47 copyvae
# 32copyvae55 copyvae
# 54919  copyvae
#
# 54
# copyvae copyvae41
#  copyvae
# 1356 copyvae 38
#  copyvae61 29 copyvae
#
# copyvaecopyvae
#
# copyvae
# 6copyvae
#  copyvae
# 17 copyvae
# 20 copyvae
# 63 copyvae
# 65 rna
# 66 rna
# 68 rna
# 69 rna
# 70 rna73 rna
#
# 74 rna
# 75 rna
# 81 rna
# 6777 76 rna
#  79 rna
# 8284  rnarna
#
# 86rna
# rna83 rna
# 78 rna
# 7289 rna
# rna
# 94 rna
#
#  92 85 rna
# rnarna87 rna
#
# 9590
# rna88
# 9996  rna
# 93 rna
#  102 rna
#  rna
# 101 rna103rna
# rna
# rna
#
# 10071  rna91
#  rna
# rna110 rna
#
# 109 rna
# 80108  98 rnarna
# rna
#
# 118 115rna rna120
# rna
# 106 121 rna97 114104
# rna rnarna
#  rna
# 107 rna112 rna
#
#
# 113 rna
#
#
# 117 rna
# 111 122 rna
# 126rna
# 119 rna
#
# 116 rna 123 rna
# rna105
# rna125
#  127rna124
#  rnarna
#
# 128 rna
# 65 copykat66
# copykat
# 68 copykat
# 69 copykat
# 73 copykat
# 75 copykat
#  74copykat
# 81 copykat
# 70 copykat
# 77 copykat
# 82 76 copykat
# 79 copykat
# copykat
# 78 copykat
# 8483 copykat
# 86 copykat
#
# 89  copykatcopykat
# 85 copykat
# 99 copykat94
#  copykat
# 8792 copykat
# 93 copykat
#  102 copykat
# 101 copykat
# 103 copykat
# copykat90110 copykat
#
#  96 copykat
# copykat72
#  copykat
# 67 88 copykat
# copykat109
# 95 copykat
#  71 copykat
# 91 copykat
# copykat
# 115 copykat
# 106100120 copykat
# 9897  copykat 80 copykat
# 104
#  copykat
# 221 copyvae
# 224 copyvae
# 225 copyvae
# 222 copyvae
# 227 copyvae
# 228 copyvae
# 230223copyvae  copyvae
#
# 229 copyvae
# 226 copyvae
# 232 copyvae
# 238 copyvae
# 231 copyvae
# 236 copyvae
# 234 copyvae
# 237 copyvae
# 235 copyvae
# 233 copyvae
# 242 copyvae
# 240 copyvae
# 241 copyvae
# 247 copyvae
# 239 copyvae
# 244248 copyvae
#  copyvae
# 246 copyvae
# 243 copyvae
# 245 copyvae
# 249 copyvae
# 250 copyvae

# %%
recall_df
# Out:
#        metric   tool  top_n    recall  min_duplicates  max_duplicates  \
# 0      cosine    rna      1  0.005263               1               1
# 1      cosine    rna      5  0.011842               1               1
# 2      cosine    rna     10  0.018421               1               1
# 3      cosine    rna     25  0.034211               1               1
# 4      cosine    rna     50  0.059211               1               1
# ...       ...    ...    ...       ...             ...             ...
# 19495  random  other      5  0.013158               1               1
# 19496  random  other     10  0.019737               1               1
# 19497  random  other     25  0.038158               1               1
# 19498  random  other     50  0.061842               1               1
# 19499  random  other    100  0.135526               1               1
#
#        median_duplicates  mean_duplicates
# 0                    1.0              1.0
# 1                    1.0              1.0
# 2                    1.0              1.0
# 3                    1.0              1.0
# 4                    1.0              1.0
# ...                  ...              ...
# 19495                1.0              1.0
# 19496                1.0              1.0
# 19497                1.0              1.0
# 19498                1.0              1.0
# 19499                1.0              1.0
#
# [19500 rows x 8 columns]

# %%
recall_df.to_csv(workflow_dir/"cell2cell_recall.csv",index=False)

# %%
def get_accs(rep)->dict[str,float]:
    methods = ["cosine","pearson","spearman","kendall"]
    tools = ["rna","copyvae","copykat"]
    matches = []
    gen = np.random.default_rng(rep)
    for method in methods:
        for tool in tools:
            df = pd.read_csv(results_dir/f'replicate_{rep}_{tool}_{method}.tsv',sep='\t',index_col=0).iloc[:n_cells,n_cells:]
            best_score = df.apply(lambda x:max(abs(x)),axis=0)
            is_best_match = df.apply(lambda x : abs(x) == best_score,axis=1).T.replace(True,{col:col for col in df.T.columns}).replace(False,pd.NA).T
            cell_matches = is_best_match.apply(lambda x:[k.split("_")[0] for k in x if not pd.isna(k)][0] if x.count() > 0 else "NA",axis=0)
            matches.append(pd.Series(cell_matches,name=f"{method}_{tool}").sort_index())
    random = pd.Series([x.split("_")[0] for x in pd.Series(df.index).sample(n=len(df.columns),random_state=rep,replace=True)],index = df.columns,name="random_other").sort_index()
    matches.append(random)
    madna_df = pd.read_csv(clonealign_assignments/f"replicate_{rep}_macrodna.tsv",sep="\t",index_col=0)
    madna_df["macrodna_other"] = madna_df["predict_cell"].apply(lambda x: x.split("_")[0])
    matches.append(madna_df["macrodna_other"])
    matches_df = pd.concat(matches,axis=1)
    matches_df["GroundTruth"] = [gt[x] for x in matches_df.index]
    return {c : sum(matches_df[c]==matches_df["GroundTruth"]) / matches_df[c].count() for c in matches_df.columns if c != "CellLine"}
if __name__ == "__main__":
    p = mp.Pool()
    res = list(p.map_async(get_accs,range(1,n_bootstrap+1)).get())
    top_df = pd.DataFrame(res)
# Out:
# Process ForkPoolWorker-254:
# Process ForkPoolWorker-253:
# Process ForkPoolWorker-224:
# Process ForkPoolWorker-239:
# Process ForkPoolWorker-193:
# Process ForkPoolWorker-198:
# Process ForkPoolWorker-213:
# Process ForkPoolWorker-234:
# Process ForkPoolWorker-223:
# Process ForkPoolWorker-246:
# Process ForkPoolWorker-205:
# Process ForkPoolWorker-195:
# Process ForkPoolWorker-255:
# Process ForkPoolWorker-214:
# Process ForkPoolWorker-204:
# Process ForkPoolWorker-241:
# Process ForkPoolWorker-237:
# Process ForkPoolWorker-209:
# Process ForkPoolWorker-226:
# Process ForkPoolWorker-200:
# Process ForkPoolWorker-217:
# Process ForkPoolWorker-208:
# Process ForkPoolWorker-247:
# Process ForkPoolWorker-215:
# Process ForkPoolWorker-232:
# Process ForkPoolWorker-229:
# Process ForkPoolWorker-199:
# Process ForkPoolWorker-203:
# Process ForkPoolWorker-225:
# Process ForkPoolWorker-201:
# Process ForkPoolWorker-251:
# Process ForkPoolWorker-230:
# Process ForkPoolWorker-243:
# Process ForkPoolWorker-197:
# Process ForkPoolWorker-240:
# Process ForkPoolWorker-227:
# Process ForkPoolWorker-211:
# Process ForkPoolWorker-221:
# Process ForkPoolWorker-252:
# Process ForkPoolWorker-222:
# Process ForkPoolWorker-219:
# Process ForkPoolWorker-238:
# Process ForkPoolWorker-196:
# Process ForkPoolWorker-212:
# Process ForkPoolWorker-236:
# Process ForkPoolWorker-216:
# Process ForkPoolWorker-228:
# Process ForkPoolWorker-207:
# Process ForkPoolWorker-233:
# Process ForkPoolWorker-256:
# Process ForkPoolWorker-220:
# Process ForkPoolWorker-202:
# Process ForkPoolWorker-250:
# Process ForkPoolWorker-194:
# Process ForkPoolWorker-242:
# Process ForkPoolWorker-248:
# Process ForkPoolWorker-245:
# Process ForkPoolWorker-244:
# Process ForkPoolWorker-218:
# Process ForkPoolWorker-249:
# Process ForkPoolWorker-210:
# Process ForkPoolWorker-231:
# Process ForkPoolWorker-235:
# Process ForkPoolWorker-206:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 387, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/kasper01/tools/miniforge/envs/merge_dna_rna/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
top_df
# Out:
#      cosine_rna  cosine_copyvae  cosine_copykat  pearson_rna  pearson_copyvae  \
# 0      0.005263        0.000000        0.013158     0.006579         0.002632
# 1      0.001316        0.000000        0.010526     0.003947         0.002632
# 2      0.005263        0.000000        0.010526     0.006579         0.002632
# 3      0.005263        0.001316        0.010526     0.003947         0.002632
# 4      0.005263        0.000000        0.011842     0.007895         0.003947
# ..          ...             ...             ...          ...              ...
# 245    0.002632        0.000000        0.013158     0.003947         0.003947
# 246    0.005263        0.000000        0.009211     0.006579         0.001316
# 247    0.003947        0.000000        0.013158     0.005263         0.002632
# 248    0.003947        0.000000        0.010526     0.006579         0.003947
# 249    0.007895        0.000000        0.011842     0.007895         0.005263
#
#      pearson_copykat  spearman_rna  spearman_copyvae  spearman_copykat  \
# 0           0.015789      0.006579          0.001316          0.011842
# 1           0.014474      0.003947          0.001316          0.014474
# 2           0.017105      0.007895          0.001316          0.015789
# 3           0.018421      0.003947          0.001316          0.013158
# 4           0.015789      0.005263          0.001316          0.013158
# ..               ...           ...               ...               ...
# 245         0.014474      0.005263          0.001316          0.013158
# 246         0.014474      0.007895          0.001316          0.014474
# 247         0.017105      0.003947          0.001316          0.013158
# 248         0.014474      0.003947          0.001316          0.014474
# 249         0.014474      0.005263          0.001316          0.011842
#
#      kendall_rna  kendall_copyvae  kendall_copykat  random_other  \
# 0       0.003947         0.001316         0.013158      0.000000
# 1       0.001316         0.001316         0.014474      0.000000
# 2       0.003947         0.001316         0.015789      0.001316
# 3       0.002632         0.001316         0.018421      0.002632
# 4       0.002632         0.001316         0.011842      0.001316
# ..           ...              ...              ...           ...
# 245     0.005263         0.001316         0.014474      0.003947
# 246     0.003947         0.001316         0.014474      0.000000
# 247     0.003947         0.001316         0.014474      0.000000
# 248     0.002632         0.001316         0.015789      0.000000
# 249     0.002632         0.001316         0.014474      0.001316
#
#      macrodna_other  GroundTruth
# 0          0.009211          1.0
# 1          0.007895          1.0
# 2          0.007895          1.0
# 3          0.006579          1.0
# 4          0.010526          1.0
# ..              ...          ...
# 245        0.007895          1.0
# 246        0.009211          1.0
# 247        0.010526          1.0
# 248        0.006579          1.0
# 249        0.010526          1.0
#
# [250 rows x 15 columns]

# %%
long_df = pd.melt(top_df.drop(columns="GroundTruth"),var_name="method",value_name="accuracy")
long_df["tool"] = long_df["method"].apply(lambda x:x.split("_")[1])
long_df["method"] = long_df["method"].apply(lambda x:x.split("_")[0])
long_df
# Out:
#         method  accuracy   tool
# 0       cosine  0.005263    rna
# 1       cosine  0.001316    rna
# 2       cosine  0.005263    rna
# 3       cosine  0.005263    rna
# 4       cosine  0.005263    rna
# ...        ...       ...    ...
# 3495  macrodna  0.007895  other
# 3496  macrodna  0.009211  other
# 3497  macrodna  0.010526  other
# 3498  macrodna  0.006579  other
# 3499  macrodna  0.010526  other
#
# [3500 rows x 3 columns]

# %%
clonealign_df = pd.read_csv(results_dir / "clonealign_assignments",index_col = 0)
clonealign_df["gt"] = clonealign_df["RNA"].apply(lambda x:gt[x])
clonealign_df["correct"] = clonealign_df["DNA"] == clonealign_df["gt"]
sum(clonealign_df["correct"])
# Out:
# 1

# %%
long_df = pd.concat(
    [
        long_df,
        pd.DataFrame({"method":["clonealign"],"accuracy":[sum(clonealign_df["correct"])/len(clonealign_df["correct"])],"tool":["other"]})
    ]
)
long_df
# Out:
#           method  accuracy   tool
# 0         cosine  0.005263    rna
# 1         cosine  0.001316    rna
# 2         cosine  0.005263    rna
# 3         cosine  0.005263    rna
# 4         cosine  0.005263    rna
# ...          ...       ...    ...
# 3496    macrodna  0.009211  other
# 3497    macrodna  0.010526  other
# 3498    macrodna  0.006579  other
# 3499    macrodna  0.010526  other
# 0     clonealign  0.001316  other
#
# [3501 rows x 3 columns]

# %%
long_df[long_df["method"]=="random"]
# Out:
#       method  accuracy   tool
# 3000  random  0.000000  other
# 3001  random  0.000000  other
# 3002  random  0.001316  other
# 3003  random  0.002632  other
# 3004  random  0.001316  other
# ...      ...       ...    ...
# 3245  random  0.003947  other
# 3246  random  0.000000  other
# 3247  random  0.000000  other
# 3248  random  0.000000  other
# 3249  random  0.001316  other
#
# [250 rows x 3 columns]

# %%
long_df.to_csv(workflow_dir / "cell2cell_accuracy.csv",index=False)

# %%
fig,ax = plt.subplots(figsize=(16,9))
sns.boxplot(stats_df,x="tool",y="accuracy",hue="method",ax=ax,fill=False)
plt.show()
